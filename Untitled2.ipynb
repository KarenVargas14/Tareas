# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenVargas14/Tareas/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Functions Exercises**

# %% [markdown]
# 1.

# %%
def greet():
    print("Hello, world!")

# %%
greet()
# Out:
# Hello, world!

# %% [markdown]
# 2.

# %%
def show_name(name):
    print("Hello", name)

# %%
show_name("Karen")
# Out:
# Hello Karen

# %% [markdown]
# 3.

# %%
def add(a, b):
    return a + b

# %%
result = add(5, 3)
print("Sum:", result)
# Out:
# Sum: 8

# %% [markdown]
# 4.

# %%
def subtract(a, b):
    return a - b

# %%
result = subtract(10, 4)
print("subtraction:", result)
# Out:
# subtraction: 6

# %% [markdown]
# 5.

# %%
def multiply(a, b):
    return a * b

# %%
result = multiply(4, 5)
print("multiplication:", result)
# Out:
# multiplication: 20

# %% [markdown]
# 6.

# %%
def divide(a, b):
    return a / b

# %%
result = divide(10, 2)
print("Division:", result)
# Out:
# Division: 5.0

# %% [markdown]
# 7.

# %%
def is_even(number):
    return number % 2 == 0

# %%
print(is_even(4))
# Out:
# True

# %%
print(is_even(7))
# Out:
# False

# %% [markdown]
# 8.

# %%
def find_max(a, b):
    if a > b:
        return a
    else:
        return b

# %%
print(find_max(10, 5))
# Out:
# 10

# %%
print(find_max(3, 8))
# Out:
# 8

# %% [markdown]
# 9.

# %%
def square(number):
    return number ** 2

# %%
print("square:", square(4))
# Out:
# square: 16

# %% [markdown]
# 10.

# %%
def cube(number):
    return number ** 3

# %%
print("cube:", cube(3))
# Out:
# cube: 27

# %% [markdown]
# 11.

# %%
def count_letters(word):
    return len(word)

# %%
print("number of letters:", count_letters("python"))
# Out:
# number of letters: 6

# %% [markdown]
# 12.

# %%
def convert_to_upper(text):
    return text.upper()

# %%
print(convert_to_upper("hello world"))
# Out:
# HELLO WORLD

# %% [markdown]
# 13.

# %%
def calculate_area(length, width):
    return length * width

# %%
print("Area:", calculate_area(5, 3))
# Out:
# Area: 15

# %% [markdown]
# 14.

# %%
def average(numbers):
    return sum(numbers) / len(numbers)

# %%
print("Average:", average([10, 20, 30, 40]))
# Out:
# Average: 25.0

# %% [markdown]
# 15.

# %%
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# %%
print("Factorial:", factorial(5))
# Out:
# Factorial: 120
