# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenVargas14/Tareas/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Dictionary Exercises**

# %% [markdown]
# 1.

# %%
estudiante = {
    "nombre": "Karen",
    "edad": 17,
    "grado": "first semester"
}

# %% [markdown]
# 2.

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}

# %%
print("brand:", car["brand"])
# Out:
# brand: Toyota

# %% [markdown]
# 3.

# %%
print("year:", car["year"])
# Out:
# year: 2020

# %% [markdown]
# 4.

# %%
person = {"name": "Alice", "age": 25}

# %%
person["city"] = "Bogota"

# %%
print("updated dictionary:", person)
# Out:
# updated dictionary: {'name': 'Alice', 'age': 25, 'city': 'Bogota'}

# %% [markdown]
# 5.

# %%
person["age"] = 26

# %%
print("updated dictionary:", person)
# Out:
# updated dictionary: {'name': 'Alice', 'age': 26, 'city': 'Bogota'}

# %% [markdown]
# 6.

# %%
del person["city"]

# %%
print("updated dictionary:", person)
# Out:
# updated dictionary: {'name': 'Alice', 'age': 26}

# %% [markdown]
# 7.

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}

# %%
print("keys:", fruits.keys())
# Out:
# keys: dict_keys(['apple', 'banana', 'orange'])

# %% [markdown]
# 8.

# %%
print("values:", fruits.values())
# Out:
# values: dict_values([3, 5, 2])

# %% [markdown]
# 9.

# %%
for keys, values in fruits.items():
    print(keys, ":", values)
# Out:
# apple : 3
# banana : 5
# orange : 2

# %% [markdown]
# 10.

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}

# %%
print("Luis" in grades)
# Out:
# True

# %% [markdown]
# 11.

# %%
print("Pedro" in grades)
# Out:
# False

# %% [markdown]
# 12.

# %%
numbers = {"a": 10, "b": 20, "c": 30}

# %%
sum = sum(numbers.values())

# %%
print("Total sum:", sum)
# Out:
# Total sum: 60

# %% [markdown]
# 13.

# %%
inventory = {"pens": 10, "notebooks": 5, "erasers": 8}

# %%
amount = len(inventory)

# %%
print("number of elements:", amount)
# Out:
# number of elements: 3

# %% [markdown]
# 14.

# %%
countries = {"Colombia": "Bogota", "France": "Paris", "Japan": "Tokyo"}

# %%
for pais, capital in countries.items():
    print(pais, ":", capital)
# Out:
# Colombia : Bogota
# France : Paris
# Japan : Tokyo

# %% [markdown]
# 15.

# %%
temperatures = {"Monday": 22, "Tuesday": 24, "Wednesday": 21, "Thursday": 23}

# %%
max_temp = max(temperatures.values())

# %%
print("Highest temperature:", max_temp)
# Out:
# Highest temperature: 24
