# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenVargas14/Tareas/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Lists Exercises**

# %% [markdown]
# 1.

# %%
FruitS = ['apple', 'banana', 'orange', 'grape']

# %% [markdown]
# 2.

# %%
Numbers = [4, 8, 15, 16, 23, 42]

# %%
First = Numbers[0]

# %%
print("first element:", First)
# Out:
# first element: 4

# %% [markdown]
# 3.

# %%
Last = Numbers[-1]

# %%
print("Last element:", Last)
# Out:
# Last element: 42

# %% [markdown]
# 4.

# %%
Colors = ['red', 'blue', 'green', 'yellow']

# %%
Second = Colors[1]

# %%
Third = Colors[2]

# %%
print("Second element:", Second)
print("Third element:", Third)
# Out:
# Second element: blue
# Third element: green

# %% [markdown]
# 5.

# %%
Citys = ['Bogota', 'Ibague', 'Medellin', 'Cali', 'Barranquilla']

# %%
Elements = len(Citys)

# %%
print("Number of elements:", Elements)
# Out:
# Number of elements: 5

# %% [markdown]
# 6.

# %%
Animals = ['dog', 'cat', 'rabbit']

# %%
Animals.append("Hamster")

# %%
print("updated list:", Animals)
# Out:
# updated list: ['dog', 'cat', 'rabbit', 'Hamster']

# %% [markdown]
# 7.

# %%
Animals.insert(1, "bird")

# %%
print("updated list:", Animals)
# Out:
# updated list: ['dog', 'bird', 'cat', 'rabbit', 'Hamster']

# %% [markdown]
# 8.

# %%
numbers = [10, 20, 30, 40, 50]

# %%
numbers.remove(30)

# %%
print("updated list:", numbers)
# Out:
# updated list: [10, 20, 40, 50]

# %% [markdown]
# 9.

# %%
letters = ['a', 'b', 'c', 'd', 'e']

# %%
letters.pop()
# Out:
# 'e'

# %%
print("updated list:", letters)
# Out:
# updated list: ['a', 'b', 'c', 'd']

# %% [markdown]
# 10.

# %%
Names = ['Ana', 'Luis', 'Maria', 'Pedro']

# %%
Check = "Maria" in Names

# %%
print(Check)
# Out:
# True

# %% [markdown]
# 11.

# %%
numberS = [5, 2, 9, 1, 7]

# %%
numberS.sort()

# %%
print("updated list:", numberS)
# Out:
# updated list: [1, 2, 5, 7, 9]

# %% [markdown]
# 12.

# %%
numberS.sort(reverse=True)

# %%
print("updated list:", numberS)
# Out:
# updated list: [9, 7, 5, 2, 1]

# %% [markdown]
# 13.

# %%
numbeRs = [3, 6, 9, 12, 15]

# %%
x2 = [n * 2 for n in numbeRs]

# %%
print("updated list:", x2)
# Out:
# updated list: [6, 12, 18, 24, 30]

# %% [markdown]
# 14.

# %%
words = ['python', 'list', 'exercise', 'practice']

# %%
for word in words:
    print(word)
# Out:
# python
# list
# exercise
# practice

# %% [markdown]
# 15.

# %%
grades = [80, 75, 90, 85, 95]

# %%
average = sum(grades) / len(grades)

# %%
print("average:", average)
# Out:
# average: 85.0
